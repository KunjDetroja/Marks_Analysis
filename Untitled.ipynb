# %%
import pandas as pd

# %%
df=pd.read_csv('Final_Marksheet.csv')
df.head(7)
# Out:
#    id  Roll_No Div Mentor Branch      Enrollment  \
# 0   1        1  C1    BNS     IT  21002170210071
# 1   2        2  C1    MPH     IT  21002170210060
# 2   3        3  C1    BKV    CSD  21002170310039
# 3   4        4  C1    ASP     IT  21002170210066
# 4   5        5  C1    JVC     IT  21002170210015
# 5   6        6  C1    AKS     IT  21002170210056
# 6   7        7  C1    MVK     IT  21002170210083
#
#                              Name  DM_T1  DM_T2  DM_T3  ...  TOC_T3  TOC_T4  \
# 0         PATEL SHREY KALPESHBHAI   25.0   22.5   25.0  ...    25.0    24.0
# 1        PATEL DHAIRYA LALITKUMAR   25.0   22.0   25.0  ...    24.5    23.0
# 2         VADHER SAHIL DINESHBHAI   20.5   21.0   22.5  ...    25.0    24.0
# 3               PATEL HENIL KULIN   25.0   21.0   21.0  ...    23.5    24.0
# 4        DESAI RADHIKA BHARATBHAI   22.5   22.5   25.0  ...    24.0    22.0
# 5         PARMAR MANSI RAJESHBHAI   25.0   18.5   23.0  ...    24.5    25.0
# ...
